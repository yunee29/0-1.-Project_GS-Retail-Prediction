# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import seaborn as sns
from sklearn.model_selection import train_test_split
from datetime import datetime as dt
import warnings
import matplotlib.font_manager as fm
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
#!rm ~/.cache/matplotlib -rf

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# # **0.데이터 전처리**

# %%
final_data = pd.read_csv('./gdrive/My Drive/빅콘 대상팀/data/model_data.csv')

# %%
gu = pd.read_excel('./gdrive/My Drive/빅콘 대상팀/data/지역데이터/구_동.xlsx')
gs = pd.read_csv('./gdrive/My Drive/빅콘 대상팀/data/all_amt.csv',parse_dates=['STD_YMD'])
#gs = gs.drop(['Unnamed: 0'],axis=1)
gs = pd.concat([gs.iloc[:,[0,1]],gs.filter(like='GS')],axis=1)
gs = pd.merge(gs,gu,on='HDONG_NM')
gs['CITY'] = gs['HDONG_GU'].apply(lambda x: x[0:2])
gs_seoul = gs.query('CITY == "서울" & STD_YMD > "2020"')

gs_eat = gs_seoul.iloc[:,[0,1,3]].sort_values(['HDONG_NM','STD_YMD'])
gs_snack = gs_seoul.iloc[:,[0,1,4]].sort_values(['HDONG_NM','STD_YMD'])
gs_drink = gs_seoul.iloc[:,[0,1,5]].sort_values(['HDONG_NM','STD_YMD'])

# %%
final_data4 = final_data.drop(['COVID_CNT','covid_p1','sc_m1','cj_m1','covid_p1','최저기온','최고기온','일강수량'],axis=1) #최종사용데이터

# %%
def build_data(data,dong,cat):

  X = data.query('HDONG_NM==@dong').reset_index(drop=True)
  
  if cat == "식사":
    eat = gs_eat.query('HDONG_NM==@dong').reset_index(drop=True)
    X['self_m7'] = eat['GS_식사'].shift(7)
    X['y'] = eat['GS_식사']
  elif cat == "간식":
    snack = gs_snack.query('HDONG_NM==@dong').reset_index(drop=True)
    X['self_m7'] = snack['GS_간식'].shift(7)
    X['y'] = snack['GS_간식']
  elif cat == "마실거리":
    drink = gs_drink.query('HDONG_NM==@dong').reset_index(drop=True)
    X['self_m7'] = drink['GS_마실거리'].shift(7)
    X['y'] = drink['GS_마실거리']
  
  X.index = X['STD_YMD']
  del X['STD_YMD'],X['HDONG_NM']

  return X

# %%
from sklearn.preprocessing import MinMaxScaler 

def minmax_scalar(X):
  idx = X.index
  col = X.columns

  scalar = MinMaxScaler()
  scaled_X = pd.DataFrame(scalar.fit_transform(X))
  scaled_X.index = idx
  scaled_X.columns = col

  return scaled_X

# %%
def split_xy(dataset, time_steps, y_column):

  x, y = list(), list()
  for i in range(len(dataset)):
    x_end_number = i + time_steps
    y_end_number = x_end_number + y_column

    if y_end_number > len(dataset):
      break
    tmp_x = np.array(dataset)[i:x_end_number, :]
    tmp_y = np.array(dataset)[x_end_number:y_end_number, -1]
    x.append(tmp_x)
    y.append(tmp_y)
  return np.array(x), np.array(y)

# %%
import numpy as np
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import mean_absolute_error

def RMSLE_fun(origin,pred):
  rmsle = np.sqrt(mean_squared_log_error(origin+1, pred+1))
  return rmsle

# %%
def train_test_split(n,X,y):
  if isinstance(X, pd.DataFrame):
    total = X.shape[0]
    X_train,X_test = X.iloc[:total-n, :],X.iloc[-n:, :]
    y_train,y_test = y[:total-n],y[-n:]
  else :
    total = X.shape[0]
    X_train,X_test = X[:total-n, :],X[-n:, :]
    y_train,y_test = y[:total-n],y[-n:]
  return X_train,X_test,y_train,y_test

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM, GRU
from keras.callbacks import EarlyStopping

# %%
def data_pipeline(data, dong, cat, time_steps, y_columns):
  data = build_data(data,dong,cat)
  
  #y = data['y']
  #del data['y']
  min = data['y'].min()
  max = data['y'].max()

  X = minmax_scalar(data)
  #Xy = pd.concat([X,y],axis=1)
  Xy = X.dropna()
  
  X,y = split_xy(Xy,time_steps,y_columns)

  X_train, y_train = X[:-7],y[:-7]
  X_test, y_test = X[-7:],y[-7:]

  X_test=X_test.reshape(-1,time_steps,X_train.shape[2])
  y_test=y_test.reshape(-1,y_columns)



  return X_train,y_train,X_test,y_test,min,max

# %% [markdown]
# # **1. LSTM**

# %%
def LSTM_fun(data, dong, cat):
  
  X_train,y_train,X_test,y_test,min,max = data_pipeline(data, dong, cat,7,1)

  model = Sequential()
  model.add(LSTM(100, input_shape = (None, X_train.shape[2])))
  model.add(Dense(10))
  model.add(Dense(1))

  model.compile(optimizer='adam', loss='mse')
  early_stopping = EarlyStopping(monitor='val_loss', patience=30, mode='min', restore_best_weights=True)
  model.fit(X_train, y_train, epochs=5000, batch_size=32, verbose=0, callbacks=[early_stopping], validation_data = (X_test, y_test))

  y_pred = model.predict(X_test, batch_size=1)
  #y_pred = y_pred.reshape(-1, 1) *(max-min)+min
  #y_test = y_test *(max-min)+min

  mse = np.mean((y_test-y_pred)**2)
  rmse = np.sqrt(mse)
  mae = mean_absolute_error(y_test, y_pred)
  rmsle = RMSLE_fun(np.array(y_test), np.array(y_pred))

  return mse, rmse, mae, rmsle

# %% [markdown]
# # **2. GRU**

# %%
def GRU_fun(data, dong, cat):
  
  X_train,y_train,X_test,y_test,min,max = data_pipeline(data, dong, cat,7,1)

  model = Sequential()
  model.add(GRU(100, input_shape = (None, X_train.shape[2])))
  model.add(Dense(10))
  #model.add(Dense(7))
  model.add(Dense(1))

  model.compile(optimizer='adam', loss='mse')
  early_stopping = EarlyStopping(monitor='val_loss', patience=50, mode='min', restore_best_weights=True)
  model.fit(X_train, y_train, epochs=5000, batch_size=32, verbose=0, callbacks=[early_stopping], validation_data = (X_test, y_test))

  
  y_pred = model.predict(X_test, batch_size=1)
  #y_pred = y_pred.reshape(-1, 1) *(max-min)+min
  #y_test = y_test *(max-min)+min

  mse = np.mean((y_test-y_pred)**2)
  rmse = np.sqrt(mse)
  mae = mean_absolute_error(y_test, y_pred)
  rmsle = RMSLE_fun(np.array(y_test), np.array(y_pred))

  return mse, rmse, mae, rmsle

# %% [markdown]
# # **3. LSTM & GRU results**

# %%
dong_list = list(final_data['HDONG_NM'].unique())
dong_list.remove('상계8동')

# %%
# LSTM
MSE_eat = []
RMSE_eat = []
MAE_eat = []
RMSLE_eat = []

MSE_snack = []
RMSE_snack = []
MAE_snack = []
RMSLE_snack = []

MSE_drink = []
RMSE_drink = []
MAE_drink = []
RMSLE_drink = []

for cat in ['식사', '간식', '마실거리']:
  for dong in dong_list:
    mse, rmse, mae, rmsle = LSTM_fun(final_data4, dong, cat)
    #print('{0}, {1}, {2}, {3}, {4}, {5}'.format(dong, cat, mse, rmse, mae, rmsle))

    if cat == '식사':
      MSE_eat.append(mse)
      RMSE_eat.append(rmse)
      MAE_eat.append(mae)
      RMSLE_eat.append(rmsle)
      
    elif cat == '간식':
      MSE_snack.append(mse)
      RMSE_snack.append(rmse)
      MAE_snack.append(mae)
      RMSLE_snack.append(rmsle)
      
    else: 
      MSE_drink.append(mse)
      RMSE_drink.append(rmse)
      MAE_drink.append(mae)
      RMSLE_drink.append(rmsle)

# %%
lstm_result = pd.DataFrame({'동':dong_list,
              '식사_MSE':MSE_eat,
              '식사_RMSE':RMSE_eat,
              '식사_MAE':MAE_eat,
              '식사_RMSLE':RMSLE_eat,
              '간식_MSE':MSE_snack,
              '간식_RMSE':RMSE_snack,
              '간식_MAE':MAE_snack,
              '간식_RMSLE':RMSLE_snack,
              '마실거리_MSE':MSE_drink,
              '마실거리_RMSE':RMSE_drink,
              '마실거리_MAE':MAE_drink,
              '마실거리_RMSLE':RMSLE_drink})

# %%
lstm_result.mean()
# Out:
# 식사_MSE        0.015842
# 식사_RMSE       0.115357
# 식사_MAE        0.096041
# 식사_RMSLE      0.045043
# 간식_MSE        0.006963
# 간식_RMSE       0.072412
# 간식_MAE        0.060080
# 간식_RMSLE      0.031221
# 마실거리_MSE      0.019499
# 마실거리_RMSE     0.126972
# 마실거리_MAE      0.107811
# 마실거리_RMSLE    0.047043
# dtype: float64

# %%
# GRU
MSE_eat = []
RMSE_eat = []
MAE_eat = []
RMSLE_eat = []

MSE_snack = []
RMSE_snack = []
MAE_snack = []
RMSLE_snack = []

MSE_drink = []
RMSE_drink = []
MAE_drink = []
RMSLE_drink = []

for cat in ['식사', '간식', '마실거리']:
  for dong in dong_list:
    mse, rmse, mae, rmsle = GRU_fun(final_data4, dong, cat)
    print('{0}, {1}, {2}, {3}, {4}, {5}'.format(dong, cat, mse, rmse, mae, rmsle))

    if cat == '식사':
      MSE_eat.append(mse)
      RMSE_eat.append(rmse)
      MAE_eat.append(mae)
      RMSLE_eat.append(rmsle)
      
    elif cat == '간식':
      MSE_snack.append(mse)
      RMSE_snack.append(rmse)
      MAE_snack.append(mae)
      RMSLE_snack.append(rmsle)
      
    else: 
      MSE_drink.append(mse)
      RMSE_drink.append(rmse)
      MAE_drink.append(mae)
      RMSLE_drink.append(rmsle)

# %%
gru_result = pd.DataFrame({'동':dong_list,
              '식사_MSE':MSE_eat,
              '식사_RMSE':RMSE_eat,
              '식사_MAE':MAE_eat,
              '식사_RMSLE':RMSLE_eat,
              '간식_MSE':MSE_snack,
              '간식_RMSE':RMSE_snack,
              '간식_MAE':MAE_snack,
              '간식_RMSLE':RMSLE_snack,
              '마실거리_MSE':MSE_drink,
              '마실거리_RMSE':RMSE_drink,
              '마실거리_MAE':MAE_drink,
              '마실거리_RMSLE':RMSLE_drink})

# %%
gru_result.mean()
# Out:
# 식사_MSE        0.015914
# 식사_RMSE       0.116324
# 식사_MAE        0.097095
# 식사_RMSLE      0.045337
# 간식_MSE        0.006268
# 간식_RMSE       0.068403
# 간식_MAE        0.056125
# 간식_RMSLE      0.029493
# 마실거리_MSE      0.014624
# 마실거리_RMSE     0.111393
# 마실거리_MAE      0.091851
# 마실거리_RMSLE    0.041372
# dtype: float64

# %% [markdown]
# # **4. GRU Bayesian Optimization**

# %%
warnings.filterwarnings("ignore")

# %%
# !pip install scikit-optimize
import skopt

from skopt import gbrt_minimize, gp_minimize
from skopt.utils import use_named_args
from skopt.space import Real, Categorical, Integer  

import keras
from keras.models import Sequential
from keras.layers import Dense
import tensorflow
from tensorflow.python.keras import backend as K

dim_num_dense_layers = Integer(low=1, high=5, name='num_dense_layers')
dim_num_input_nodes = Integer(low=100, high=512, name='num_input_nodes')
dim_num_dense_nodes = Integer(low=10, high=50, name='num_dense_nodes')
dim_activation = Categorical(categories=['relu', 'sigmoid'],
                             name='activation')
dim_batch_size = Integer(low=1, high=32, name='batch_size')

dimensions = [dim_num_dense_layers,
              dim_num_input_nodes,
              dim_num_dense_nodes,
              dim_activation,
              dim_batch_size
             ]
default_parameters = [1, 512, 13, 'relu',32]
# Out:
# Collecting scikit-optimize
#   Downloading https://files.pythonhosted.org/packages/8b/03/be33e89f55866065a02e515c5b319304a801a9f1027a9b311a9b1d1f8dc7/scikit_optimize-0.8.1-py2.py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 3.4MB/s
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (0.22.2.post1)
# Collecting pyaml>=16.9
#   Downloading https://files.pythonhosted.org/packages/15/c4/1310a054d33abc318426a956e7d6df0df76a6ddfa9c66f6310274fb75d42/pyaml-20.4.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (0.16.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from pyaml>=16.9->scikit-optimize) (3.13)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-20.4.0 scikit-optimize-0.8.1

# %%
from keras.optimizers import Adam
def create_model(num_dense_layers,num_input_nodes,
                 num_dense_nodes, activation):
    #start the model making process and create our first layer

    X_train, y_train, X_test, y_test,_,_ = data_pipeline(final_data4, d, c, 7, 1) 

    model = Sequential()
    model.add(GRU(num_input_nodes, input_shape=(None, X_train.shape[2]), activation=activation
                   ))
    #create a loop making a new dense layer for the amount passed to this model.
    #naming the layers helps avoid tensorflow error deep in the stack trace.
    for i in range(num_dense_layers):
        name = 'layer_dense_{0}'.format(i+1)
        model.add(Dense(num_dense_nodes,
                 activation=activation,
                        name=name
                 ))
    #add our classification layer.
    model.add(Dense(1))
    
    #setup our optimizer and compile
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
from keras.models import load_model

@use_named_args(dimensions=dimensions)
def fitness(num_dense_layers, num_input_nodes, 
            num_dense_nodes,activation, batch_size):
  
  model = create_model(num_dense_layers=num_dense_layers,
                        num_input_nodes=num_input_nodes,
                        num_dense_nodes=num_dense_nodes,
                        activation=activation
                      )
  
  X_train,y_train,X_test,y_test,min,max = data_pipeline(final_data4, d, c,7,1) 
  
  early_stopping = EarlyStopping(monitor='val_loss', patience=30, mode='min', restore_best_weights=True)
  model.fit(X_train, y_train, epochs=5000, batch_size=32, verbose=0, callbacks=[early_stopping], validation_data = (X_test, y_test))

  y_pred = model.predict(X_test, batch_size=1)
  #y_pred = y_pred.reshape(-1,1) *(max-min) + min
  #y_test = y_test *(max-min) + min

  mse = np.mean((y_test-y_pred)**2)
  rmse = np.sqrt(mse)

  print()
  print("MSE: {}, RMSE: {}".format(mse,rmse))
  print()

  global best_mse
  
  if mse <= best_mse:
      model.save('./gdrive/My Drive/빅콘 대상팀/분석 code/GRU/models/{}{} GRU.hdf5'.format(d,c))
      best_mse = mse

  del model
  
  return mse

# %%
for c in ['식사', '간식', '마실거리']:
  for d in dong_list:
    best_mse=100

    gp_result = gp_minimize(func=fitness,
                                dimensions=dimensions,
                                n_calls=12,
                                noise= 0.01,
                                n_jobs=-1,
                                kappa = 5,
                                x0=default_parameters)
    
    
    from skopt import dump, load
    dump(gp_result, 'result.pkl')
    gp_result_loaded = load('result.pkl')

    print('{0} {1}, Best MSE={2}'.format(d, c, gp_result_loaded.fun))

    print("""Best parameters:
    - num_dense_layers=%d
    - num_input_nodes=%d
    - num_dense_nodes=%d
    - activation=%s
    - batch_size=%d"""  % (gp_result_loaded.x[0], gp_result_loaded.x[1],
                            gp_result_loaded.x[2], gp_result_loaded.x[3],
                            gp_result_loaded.x[4]))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# MSE: 0.021035586215733006, RMSE: 0.14503649959831838
#
# WARNING:tensorflow:Layer gru_98 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01596083280152513, RMSE: 0.1263361895955594
#
# WARNING:tensorflow:Layer gru_99 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017330417278759773, RMSE: 0.1316450427428233
#
# WARNING:tensorflow:Layer gru_100 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.021581685683177698, RMSE: 0.14690706478307194
#
# WARNING:tensorflow:Layer gru_101 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017319463303067155, RMSE: 0.13160343195778426
#
# WARNING:tensorflow:Layer gru_102 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.020819076838704726, RMSE: 0.14428817289959953
#
# WARNING:tensorflow:Layer gru_103 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.020812035443669365, RMSE: 0.14426377037797591
#
# WARNING:tensorflow:Layer gru_104 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014549418676214083, RMSE: 0.12062097112946024
#
# WARNING:tensorflow:Layer gru_105 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.025124680720049947, RMSE: 0.15850766770112398
#
# WARNING:tensorflow:Layer gru_106 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.011633168039167873, RMSE: 0.10785716498762553
#
# WARNING:tensorflow:Layer gru_107 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017477710978975786, RMSE: 0.13220329413057674
#
# 상계2동 식사, Best MSE=0.011633168039167873
# Best parameters:
#     - num_dense_layers=3
#     - num_input_nodes=489
#     - num_dense_nodes=48
#     - activation=relu
#     - batch_size=24
# WARNING:tensorflow:Layer gru_108 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0534245983334849, RMSE: 0.23113761773775576
#
# WARNING:tensorflow:Layer gru_109 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.061649717326895906, RMSE: 0.24829361112782566
#
# WARNING:tensorflow:Layer gru_110 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05648070450378121, RMSE: 0.23765669463278583
#
# WARNING:tensorflow:Layer gru_111 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05848472256079523, RMSE: 0.24183614816812485
#
# WARNING:tensorflow:Layer gru_112 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.06127713212250739, RMSE: 0.24754218251140025
#
# WARNING:tensorflow:Layer gru_113 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05980993243434625, RMSE: 0.24456069274179415
#
# WARNING:tensorflow:Layer gru_114 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.061150113432278615, RMSE: 0.2472854897325733
#
# WARNING:tensorflow:Layer gru_115 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05319524843566768, RMSE: 0.23064095134140356
#
# WARNING:tensorflow:Layer gru_116 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.057658549149392065, RMSE: 0.24012194641346732
#
# WARNING:tensorflow:Layer gru_117 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05807838726089869, RMSE: 0.24099457931849563
#
# WARNING:tensorflow:Layer gru_118 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05814341164774137, RMSE: 0.2411294499801743
#
# WARNING:tensorflow:Layer gru_119 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05755002075930827, RMSE: 0.2398958539852414
#
# 상계3.4동 식사, Best MSE=0.05319524843566768
# Best parameters:
#     - num_dense_layers=2
#     - num_input_nodes=339
#     - num_dense_nodes=27
#     - activation=sigmoid
#     - batch_size=20
# WARNING:tensorflow:Layer gru_120 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.013941090268900131, RMSE: 0.11807239418636403
#
# WARNING:tensorflow:Layer gru_121 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014394596666762816, RMSE: 0.1199774839991355
#
# WARNING:tensorflow:Layer gru_122 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03109054197240463, RMSE: 0.1763251030693152
#
# WARNING:tensorflow:Layer gru_123 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01469078318468472, RMSE: 0.1212055410642794
#
# WARNING:tensorflow:Layer gru_124 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014029294752788999, RMSE: 0.11844532389583388
#
# WARNING:tensorflow:Layer gru_125 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014898224174544028, RMSE: 0.12205828187609405
#
# WARNING:tensorflow:Layer gru_126 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.012824954598265858, RMSE: 0.11324731607533071
#
# WARNING:tensorflow:Layer gru_127 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.012652878444708788, RMSE: 0.11248501431172415
#
# WARNING:tensorflow:Layer gru_128 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.02041906481706777, RMSE: 0.14289529319423985
#
# WARNING:tensorflow:Layer gru_129 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.011801684397844861, RMSE: 0.1086355577048549
#
# WARNING:tensorflow:Layer gru_130 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.010011517846533374, RMSE: 0.1000575726596112
#
# WARNING:tensorflow:Layer gru_131 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.019562399504024434, RMSE: 0.13986564804849128
#
# 상계5동 식사, Best MSE=0.010011517846533374
# Best parameters:
#     - num_dense_layers=2
#     - num_input_nodes=394
#     - num_dense_nodes=21
#     - activation=relu
#     - batch_size=25
# WARNING:tensorflow:Layer gru_132 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014326872632121578, RMSE: 0.11969491481312637
#
# WARNING:tensorflow:Layer gru_133 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03497951698228379, RMSE: 0.1870281181594997
#
# WARNING:tensorflow:Layer gru_134 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.018928421700946947, RMSE: 0.1375806007435167
#
# WARNING:tensorflow:Layer gru_135 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014591549192853038, RMSE: 0.12079548498537947
#
# WARNING:tensorflow:Layer gru_136 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014781045867011757, RMSE: 0.12157732464161135
#
# WARNING:tensorflow:Layer gru_137 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017829775537629586, RMSE: 0.13352818255944918
#
# WARNING:tensorflow:Layer gru_138 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.013423990158064277, RMSE: 0.11586194439100475
#
# WARNING:tensorflow:Layer gru_139 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04018824538023456, RMSE: 0.2004700610570929
#
# WARNING:tensorflow:Layer gru_140 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.016755451850926466, RMSE: 0.12944285167952096
#
# WARNING:tensorflow:Layer gru_141 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014110957493862071, RMSE: 0.11878955128235004
#
# WARNING:tensorflow:Layer gru_142 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014832085527046382, RMSE: 0.12178704991519576
#
# WARNING:tensorflow:Layer gru_143 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01427850602205433, RMSE: 0.11949270279834803
#
# 상계6.7동 식사, Best MSE=0.013423990158064277
# Best parameters:
#     - num_dense_layers=3
#     - num_input_nodes=474
#     - num_dense_nodes=44
#     - activation=relu
#     - batch_size=26
# WARNING:tensorflow:Layer gru_144 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.012440978343030984, RMSE: 0.111539133684241
#
# WARNING:tensorflow:Layer gru_145 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.011217683290053296, RMSE: 0.10591356518432045
#
# WARNING:tensorflow:Layer gru_146 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017258057469905434, RMSE: 0.1313699260481844
#
# WARNING:tensorflow:Layer gru_147 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.010794223875600693, RMSE: 0.10389525434590693
#
# WARNING:tensorflow:Layer gru_148 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01696880391110944, RMSE: 0.13026436163091362
#
# WARNING:tensorflow:Layer gru_149 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017005711311505158, RMSE: 0.13040594814465006
#
# WARNING:tensorflow:Layer gru_150 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.019426623224482152, RMSE: 0.1393794218114071
#
# WARNING:tensorflow:Layer gru_151 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.018782897070945694, RMSE: 0.13705070985203138
#
# WARNING:tensorflow:Layer gru_152 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.018017540179001704, RMSE: 0.13422943112075572
#
# WARNING:tensorflow:Layer gru_153 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.019548146425362203, RMSE: 0.13981468601460365
#
# WARNING:tensorflow:Layer gru_154 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.012502148573315077, RMSE: 0.11181300717409884
#
# WARNING:tensorflow:Layer gru_155 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01816396274464324, RMSE: 0.13477374649627888
#
# 상계9동 식사, Best MSE=0.010794223875600693
# Best parameters:
#     - num_dense_layers=3
#     - num_input_nodes=231
#     - num_dense_nodes=47
#     - activation=relu
#     - batch_size=20
# WARNING:tensorflow:Layer gru_156 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.005697258710688726, RMSE: 0.07548018753745069
#
# WARNING:tensorflow:Layer gru_157 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.004685496298458999, RMSE: 0.06845068515697267
#
# WARNING:tensorflow:Layer gru_158 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04639020772197916, RMSE: 0.2153838613312965
#
# WARNING:tensorflow:Layer gru_159 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0024579900531731757, RMSE: 0.049578120710381667
#
# WARNING:tensorflow:Layer gru_160 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.002880060644562303, RMSE: 0.05366619647936961
#
# WARNING:tensorflow:Layer gru_161 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.005631293382536202, RMSE: 0.07504194415482719
#
# WARNING:tensorflow:Layer gru_162 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0026439190334445395, RMSE: 0.05141905321419813
#
# WARNING:tensorflow:Layer gru_163 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0040849937815255425, RMSE: 0.06391395607788289
#
# WARNING:tensorflow:Layer gru_164 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.046386722809748634, RMSE: 0.2153757711762134
#
# WARNING:tensorflow:Layer gru_165 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.009486767483104026, RMSE: 0.09740003841428414
#
# WARNING:tensorflow:Layer gru_166 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.009387678372994998, RMSE: 0.09689003237173056
#
# WARNING:tensorflow:Layer gru_167 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.004317593594456726, RMSE: 0.0657083982034011
#
# 소공동 식사, Best MSE=0.0024579900531731757
# Best parameters:
#     - num_dense_layers=4
#     - num_input_nodes=266
#     - num_dense_nodes=44
#     - activation=sigmoid
#     - batch_size=3
# WARNING:tensorflow:Layer gru_168 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.004193538295226005, RMSE: 0.06475753465988345
#
# WARNING:tensorflow:Layer gru_169 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.004836624909339359, RMSE: 0.06954584753484107
#
# WARNING:tensorflow:Layer gru_170 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.006051719771021591, RMSE: 0.07779280025183302
#
# WARNING:tensorflow:Layer gru_171 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.005084405500806099, RMSE: 0.07130501736067454
#
# WARNING:tensorflow:Layer gru_172 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.006373850183836591, RMSE: 0.07983639636053591
#
# WARNING:tensorflow:Layer gru_173 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.005121697635353869, RMSE: 0.07156603688450178
#
# WARNING:tensorflow:Layer gru_174 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0046744896477384865, RMSE: 0.0683702394886729
#
# WARNING:tensorflow:Layer gru_175 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.003944619108803835, RMSE: 0.06280620278924555
#
# WARNING:tensorflow:Layer gru_176 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.005939703642072673, RMSE: 0.0770694728285634
#
# WARNING:tensorflow:Layer gru_177 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.00523082320392756, RMSE: 0.07232443020119522
#
# WARNING:tensorflow:Layer gru_178 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.004377064319349234, RMSE: 0.06615938572379004
#
# WARNING:tensorflow:Layer gru_179 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.005126181606238217, RMSE: 0.07159735753670116
#
# 신당5동 식사, Best MSE=0.003944619108803835
# Best parameters:
#     - num_dense_layers=2
#     - num_input_nodes=364
#     - num_dense_nodes=26
#     - activation=relu
#     - batch_size=3
# WARNING:tensorflow:Layer gru_180 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01660750843087279, RMSE: 0.12887012233591147
#
# WARNING:tensorflow:Layer gru_181 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.02152828628527207, RMSE: 0.1467252067140206
#
# WARNING:tensorflow:Layer gru_182 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.020082202481197763, RMSE: 0.1417116878778803
#
# WARNING:tensorflow:Layer gru_183 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.022674519177588632, RMSE: 0.15058060691067968
#
# WARNING:tensorflow:Layer gru_184 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01618351554220762, RMSE: 0.12721444706560503
#
# WARNING:tensorflow:Layer gru_185 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.022017190324070533, RMSE: 0.14838190699701406
#
# WARNING:tensorflow:Layer gru_186 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.021270568952334198, RMSE: 0.1458443312313996
#
# WARNING:tensorflow:Layer gru_187 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.019928073656680857, RMSE: 0.14116682916563952
#
# WARNING:tensorflow:Layer gru_188 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.022932573072117508, RMSE: 0.1514350457196666
#
# WARNING:tensorflow:Layer gru_189 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.022717464731599395, RMSE: 0.1507231393369956
#
# WARNING:tensorflow:Layer gru_190 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.021545927667447735, RMSE: 0.14678531148397558
#
# WARNING:tensorflow:Layer gru_191 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.02511792703644588, RMSE: 0.1584863623042875
#
# 신당동 식사, Best MSE=0.01618351554220762
# Best parameters:
#     - num_dense_layers=1
#     - num_input_nodes=462
#     - num_dense_nodes=43
#     - activation=relu
#     - batch_size=3
# WARNING:tensorflow:Layer gru_192 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01622084365964291, RMSE: 0.12736107592056103
#
# WARNING:tensorflow:Layer gru_193 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.013470758766730028, RMSE: 0.11606359793979346
#
# WARNING:tensorflow:Layer gru_194 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.013374546930516634, RMSE: 0.11564837625542623
#
# WARNING:tensorflow:Layer gru_195 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.013560530862201733, RMSE: 0.11644969240921907
#
# WARNING:tensorflow:Layer gru_196 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.015250229657032918, RMSE: 0.12349182020293052
#
# WARNING:tensorflow:Layer gru_197 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.013653436070158084, RMSE: 0.11684791855295534
#
# WARNING:tensorflow:Layer gru_198 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.013495639421029779, RMSE: 0.11617073392653496
#
# WARNING:tensorflow:Layer gru_199 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.015401838009046534, RMSE: 0.1241041417884453
#
# WARNING:tensorflow:Layer gru_200 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.013403880287473554, RMSE: 0.1157751281038961
#
# WARNING:tensorflow:Layer gru_201 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.015840562569660644, RMSE: 0.12585929671526314
#
# WARNING:tensorflow:Layer gru_202 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01340937055998505, RMSE: 0.1157988366089446
#
# WARNING:tensorflow:Layer gru_203 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014922540318870458, RMSE: 0.12215785000920104
#
# 약수동 식사, Best MSE=0.013374546930516634
# Best parameters:
#     - num_dense_layers=2
#     - num_input_nodes=211
#     - num_dense_nodes=22
#     - activation=sigmoid
#     - batch_size=29
# WARNING:tensorflow:Layer gru_204 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0308365220669996, RMSE: 0.17560330881563593
#
# WARNING:tensorflow:Layer gru_205 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.043097035616770404, RMSE: 0.2075982553317113
#
# WARNING:tensorflow:Layer gru_206 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04069320998184459, RMSE: 0.20172558088116785
#
# WARNING:tensorflow:Layer gru_207 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05151247866070545, RMSE: 0.22696360646743666
#
# WARNING:tensorflow:Layer gru_208 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03484915472612121, RMSE: 0.18667928306622888
#
# WARNING:tensorflow:Layer gru_209 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04047353653796739, RMSE: 0.20118035823103456
#
# WARNING:tensorflow:Layer gru_210 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03621748626772186, RMSE: 0.19030892324776014
#
# WARNING:tensorflow:Layer gru_211 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.08867684956485014, RMSE: 0.2977865839235377
#
# WARNING:tensorflow:Layer gru_212 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05672532944219684, RMSE: 0.23817079888642276
#
# WARNING:tensorflow:Layer gru_213 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.07256008697257112, RMSE: 0.269369795954504
#
# WARNING:tensorflow:Layer gru_214 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.036486317087638546, RMSE: 0.1910139185704501
#
# WARNING:tensorflow:Layer gru_215 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.02895028229804743, RMSE: 0.17014782484077612
#
# 월계1동 식사, Best MSE=0.02895028229804743
# Best parameters:
#     - num_dense_layers=1
#     - num_input_nodes=100
#     - num_dense_nodes=50
#     - activation=relu
#     - batch_size=1
# WARNING:tensorflow:Layer gru_216 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.016166496323748097, RMSE: 0.12714753762361306
#
# WARNING:tensorflow:Layer gru_217 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03378195329933852, RMSE: 0.1837986759999607
#
# WARNING:tensorflow:Layer gru_218 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01680027156751954, RMSE: 0.12961586155837387
#
# WARNING:tensorflow:Layer gru_219 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017671210245217416, RMSE: 0.13293310439923314
#
# WARNING:tensorflow:Layer gru_220 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.018377421440265405, RMSE: 0.13556334844000203
#
# WARNING:tensorflow:Layer gru_221 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.026984403787426996, RMSE: 0.16426930263267997
#
# WARNING:tensorflow:Layer gru_222 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.015898973935060963, RMSE: 0.1260911334514087
#
# WARNING:tensorflow:Layer gru_223 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.027024400820390686, RMSE: 0.16439099981565503
#
# WARNING:tensorflow:Layer gru_224 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.016971161162125502, RMSE: 0.13027340926730022
#
# WARNING:tensorflow:Layer gru_225 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.018398257379937083, RMSE: 0.13564017612763957
#
# WARNING:tensorflow:Layer gru_226 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.02145860199725319, RMSE: 0.14648754894957178
#
# WARNING:tensorflow:Layer gru_227 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01570903311087522, RMSE: 0.12533568171464668
#
# 월계2동 식사, Best MSE=0.01570903311087522
# Best parameters:
#     - num_dense_layers=1
#     - num_input_nodes=486
#     - num_dense_nodes=49
#     - activation=relu
#     - batch_size=1
# WARNING:tensorflow:Layer gru_228 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.025112667632458906, RMSE: 0.1584697688281866
#
# WARNING:tensorflow:Layer gru_229 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.02750603431873517, RMSE: 0.16584943267534916
#
# WARNING:tensorflow:Layer gru_230 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.028118827145345752, RMSE: 0.1676866934057254
#
# WARNING:tensorflow:Layer gru_231 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.018595833447333426, RMSE: 0.13636654079110985
#
# WARNING:tensorflow:Layer gru_232 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01765214269071166, RMSE: 0.13286136643400767
#
# WARNING:tensorflow:Layer gru_233 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.022050972728872856, RMSE: 0.14849569936153995
#
# WARNING:tensorflow:Layer gru_234 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.019497463920943505, RMSE: 0.13963331952275396
#
# WARNING:tensorflow:Layer gru_235 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.032504002765136444, RMSE: 0.1802886651044276
#
# WARNING:tensorflow:Layer gru_236 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.019147511263343537, RMSE: 0.13837453256775084
#
# WARNING:tensorflow:Layer gru_237 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.024192255593863985, RMSE: 0.15553859840523182
#
# WARNING:tensorflow:Layer gru_238 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.028306418651216417, RMSE: 0.1682451147915339
#
# WARNING:tensorflow:Layer gru_239 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03214084909569359, RMSE: 0.17927869113671482
#
# 월계3동 식사, Best MSE=0.01765214269071166
# Best parameters:
#     - num_dense_layers=3
#     - num_input_nodes=390
#     - num_dense_nodes=15
#     - activation=relu
#     - batch_size=2
# WARNING:tensorflow:Layer gru_240 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.005929069301389879, RMSE: 0.0770004500077102
#
# WARNING:tensorflow:Layer gru_241 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.010344928551680751, RMSE: 0.10171002188418185
#
# WARNING:tensorflow:Layer gru_242 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.007456590119191391, RMSE: 0.08635154960503831
#
# WARNING:tensorflow:Layer gru_243 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.007804844301358571, RMSE: 0.08834502986223147
#
# WARNING:tensorflow:Layer gru_244 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.009016143407015998, RMSE: 0.09495337491114256
#
# WARNING:tensorflow:Layer gru_245 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.006897269333533483, RMSE: 0.08304980032205667
#
# WARNING:tensorflow:Layer gru_246 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.006654013651406262, RMSE: 0.08157213771506949
#
# WARNING:tensorflow:Layer gru_247 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.013464716277928612, RMSE: 0.11603756408132934
#
# WARNING:tensorflow:Layer gru_248 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017062849675474723, RMSE: 0.1306248432553116
#
# WARNING:tensorflow:Layer gru_249 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.006973424391686536, RMSE: 0.08350703198944708
#
# WARNING:tensorflow:Layer gru_250 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017025223481084397, RMSE: 0.13048073988556472
#
# WARNING:tensorflow:Layer gru_251 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017034998336969972, RMSE: 0.1305181915940072
#
# 을지로동 식사, Best MSE=0.005929069301389879
# Best parameters:
#     - num_dense_layers=1
#     - num_input_nodes=512
#     - num_dense_nodes=13
#     - activation=relu
#     - batch_size=32
# WARNING:tensorflow:Layer gru_252 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.013529948817403268, RMSE: 0.11631830817804766
#
# WARNING:tensorflow:Layer gru_253 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.06776654933385216, RMSE: 0.2603200901464429
#
# WARNING:tensorflow:Layer gru_254 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03811972643930198, RMSE: 0.19524273722549063
#
# WARNING:tensorflow:Layer gru_255 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.043414293429559304, RMSE: 0.20836096906464824
#
# WARNING:tensorflow:Layer gru_256 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04227870248337905, RMSE: 0.20561785545856434
#
# WARNING:tensorflow:Layer gru_257 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03223969346194092, RMSE: 0.17955415189279506
#
# WARNING:tensorflow:Layer gru_258 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017030348700091184, RMSE: 0.130500378160721
#
# WARNING:tensorflow:Layer gru_259 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.018556294658114963, RMSE: 0.13622149117563997
#
# WARNING:tensorflow:Layer gru_260 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.06979468810718796, RMSE: 0.26418684317578717
#
# WARNING:tensorflow:Layer gru_261 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.011146365101370974, RMSE: 0.10557634726287406
#
# WARNING:tensorflow:Layer gru_262 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.032240523269674234, RMSE: 0.1795564626229706
#
# WARNING:tensorflow:Layer gru_263 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.018867674545873486, RMSE: 0.13735965399590044
#
# 장충동 식사, Best MSE=0.011146365101370974
# Best parameters:
#     - num_dense_layers=3
#     - num_input_nodes=301
#     - num_dense_nodes=18
#     - activation=relu
#     - batch_size=23
# WARNING:tensorflow:Layer gru_264 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03770685562344412, RMSE: 0.19418253171550762
#
# WARNING:tensorflow:Layer gru_265 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04215608921875724, RMSE: 0.20531948085546398
#
# WARNING:tensorflow:Layer gru_266 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03758914545898125, RMSE: 0.19387920326579963
#
# WARNING:tensorflow:Layer gru_267 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05054559869695501, RMSE: 0.22482348341967084
#
# WARNING:tensorflow:Layer gru_268 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04054495559044363, RMSE: 0.20135778005938493
#
# WARNING:tensorflow:Layer gru_269 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.038750383770985206, RMSE: 0.19685117162715898
#
# WARNING:tensorflow:Layer gru_270 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.037626236455170714, RMSE: 0.19397483459245612
#
# WARNING:tensorflow:Layer gru_271 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.039933761447913795, RMSE: 0.19983433500756018
#
# WARNING:tensorflow:Layer gru_272 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04938751811409318, RMSE: 0.2222330266051677
#
# WARNING:tensorflow:Layer gru_273 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0388774496580086, RMSE: 0.19717365355951744
#
# WARNING:tensorflow:Layer gru_274 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04174712930970657, RMSE: 0.20432114259103626
#
# WARNING:tensorflow:Layer gru_275 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03608943706882216, RMSE: 0.1899722007790144
#
# 중계1동 식사, Best MSE=0.03608943706882216
# Best parameters:
#     - num_dense_layers=5
#     - num_input_nodes=100
#     - num_dense_nodes=50
#     - activation=relu
#     - batch_size=1
# WARNING:tensorflow:Layer gru_276 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.024914925029943892, RMSE: 0.1578446230631373
#
# WARNING:tensorflow:Layer gru_277 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04997000116045191, RMSE: 0.2235397082409564
#
# WARNING:tensorflow:Layer gru_278 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05036196129156064, RMSE: 0.22441470827813545
#
# WARNING:tensorflow:Layer gru_279 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04560437457918064, RMSE: 0.2135518077169581
#
# WARNING:tensorflow:Layer gru_280 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.02990987329049463, RMSE: 0.1729447116580748
#
# WARNING:tensorflow:Layer gru_281 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.018644872814547686, RMSE: 0.13654622958744664
#
# WARNING:tensorflow:Layer gru_282 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01486467090501935, RMSE: 0.12192075666193739
#
# WARNING:tensorflow:Layer gru_283 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01798705053387217, RMSE: 0.1341158101562682
#
# WARNING:tensorflow:Layer gru_284 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.043693982030857614, RMSE: 0.2090310551828546
#
# WARNING:tensorflow:Layer gru_285 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.02084491307499989, RMSE: 0.14437767512673105
#
# WARNING:tensorflow:Layer gru_286 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.032041293946109224, RMSE: 0.17900082107663423
#
# WARNING:tensorflow:Layer gru_287 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01756072281884213, RMSE: 0.1325168774867644
#
# 중계2.3동 식사, Best MSE=0.01486467090501935
# Best parameters:
#     - num_dense_layers=3
#     - num_input_nodes=190
#     - num_dense_nodes=12
#     - activation=relu
#     - batch_size=22
# WARNING:tensorflow:Layer gru_288 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01586030731811749, RMSE: 0.1259377120568636
#
# WARNING:tensorflow:Layer gru_289 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01508649993199831, RMSE: 0.12282711399360612
#
# WARNING:tensorflow:Layer gru_290 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.016341994614504463, RMSE: 0.12783581115831535
#
# WARNING:tensorflow:Layer gru_291 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014870851153704132, RMSE: 0.12194609937879985
#
# WARNING:tensorflow:Layer gru_292 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.016039921621028713, RMSE: 0.12664881215798557
#
# WARNING:tensorflow:Layer gru_293 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.015417763113083776, RMSE: 0.12416828545600433
#
# WARNING:tensorflow:Layer gru_294 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.016587162738627752, RMSE: 0.1287911593962402
#
# WARNING:tensorflow:Layer gru_295 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014812978922479975, RMSE: 0.12170858195903843
#
# WARNING:tensorflow:Layer gru_296 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.01598433350713923, RMSE: 0.12642916398971887
#
# WARNING:tensorflow:Layer gru_297 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.014422300304011341, RMSE: 0.12009288198728242
#
# ...
# WARNING:tensorflow:Layer gru_1122 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.02310928826079889, RMSE: 0.15201739459943028
#
# WARNING:tensorflow:Layer gru_1123 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.10102095286970011, RMSE: 0.31783793491290513
#
# WARNING:tensorflow:Layer gru_1124 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.061179253420697334, RMSE: 0.24734440244464262
#
# WARNING:tensorflow:Layer gru_1125 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.026474055841833054, RMSE: 0.1627084995992313
#
# WARNING:tensorflow:Layer gru_1126 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.1061299525755135, RMSE: 0.3257759238733174
#
# WARNING:tensorflow:Layer gru_1127 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04735806274243708, RMSE: 0.2176190771564779
#
# 청구동 마실거리, Best MSE=0.02310928826079889
# Best parameters:
#     - num_dense_layers=3
#     - num_input_nodes=469
#     - num_dense_nodes=41
#     - activation=relu
#     - batch_size=11
# WARNING:tensorflow:Layer gru_1128 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0015280739608408325, RMSE: 0.03909058660139078
#
# WARNING:tensorflow:Layer gru_1129 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.006418171756996713, RMSE: 0.08011349297713034
#
# WARNING:tensorflow:Layer gru_1130 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.006439687010861383, RMSE: 0.08024766046970705
#
# WARNING:tensorflow:Layer gru_1131 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0026126167049866076, RMSE: 0.05111376238339932
#
# WARNING:tensorflow:Layer gru_1132 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.06353822613233091, RMSE: 0.2520678998451229
#
# WARNING:tensorflow:Layer gru_1133 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.07534359074629682, RMSE: 0.2744878699438225
#
# WARNING:tensorflow:Layer gru_1134 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.003630467129138115, RMSE: 0.060253357824590285
#
# WARNING:tensorflow:Layer gru_1135 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.011609504429849333, RMSE: 0.10774741031620821
#
# WARNING:tensorflow:Layer gru_1136 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05802957509029375, RMSE: 0.24089328568952217
#
# WARNING:tensorflow:Layer gru_1137 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.07367118321730981, RMSE: 0.2714243600292903
#
# WARNING:tensorflow:Layer gru_1138 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0033088078948600406, RMSE: 0.05752223826364931
#
# WARNING:tensorflow:Layer gru_1139 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.005039443534749612, RMSE: 0.07098903813089463
#
# 필동 마실거리, Best MSE=0.0015280739608408325
# Best parameters:
#     - num_dense_layers=1
#     - num_input_nodes=512
#     - num_dense_nodes=13
#     - activation=relu
#     - batch_size=32
# WARNING:tensorflow:Layer gru_1140 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.016595990618112556, RMSE: 0.12882542690832643
#
# WARNING:tensorflow:Layer gru_1141 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0664083390773726, RMSE: 0.2576981549747157
#
# WARNING:tensorflow:Layer gru_1142 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017003828287161522, RMSE: 0.13039872808874142
#
# WARNING:tensorflow:Layer gru_1143 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.08010681123943006, RMSE: 0.2830314668714948
#
# WARNING:tensorflow:Layer gru_1144 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.019155632490668033, RMSE: 0.13840387455077996
#
# WARNING:tensorflow:Layer gru_1145 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.020368163350183984, RMSE: 0.14271707448719648
#
# WARNING:tensorflow:Layer gru_1146 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05478116424773664, RMSE: 0.23405376358378996
#
# WARNING:tensorflow:Layer gru_1147 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.019310368078066624, RMSE: 0.13896175041379777
#
# WARNING:tensorflow:Layer gru_1148 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0210905459490022, RMSE: 0.1452258446317397
#
# WARNING:tensorflow:Layer gru_1149 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.019807811017398997, RMSE: 0.1407402252996598
#
# WARNING:tensorflow:Layer gru_1150 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.017117601787366633, RMSE: 0.13083425311196847
#
# WARNING:tensorflow:Layer gru_1151 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.046033312976413956, RMSE: 0.21455375311658836
#
# 하계1동 마실거리, Best MSE=0.016595990618112556
# Best parameters:
#     - num_dense_layers=1
#     - num_input_nodes=512
#     - num_dense_nodes=13
#     - activation=relu
#     - batch_size=32
# WARNING:tensorflow:Layer gru_1152 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0022157670764100293, RMSE: 0.04707193512497685
#
# WARNING:tensorflow:Layer gru_1153 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0985916963289388, RMSE: 0.3139931469458192
#
# WARNING:tensorflow:Layer gru_1154 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.005810086070196749, RMSE: 0.07622392059056493
#
# WARNING:tensorflow:Layer gru_1155 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0020131215327556123, RMSE: 0.044867822910807834
#
# WARNING:tensorflow:Layer gru_1156 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.006867278313349394, RMSE: 0.0828690431545423
#
# WARNING:tensorflow:Layer gru_1157 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.002572665974854786, RMSE: 0.05072145477857261
#
# WARNING:tensorflow:Layer gru_1158 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.003480600380067394, RMSE: 0.05899661329320009
#
# WARNING:tensorflow:Layer gru_1159 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.033844728176622374, RMSE: 0.18396936749530443
#
# WARNING:tensorflow:Layer gru_1160 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05761800103778553, RMSE: 0.2400374992324856
#
# WARNING:tensorflow:Layer gru_1161 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.042990852290749774, RMSE: 0.2073423552744344
#
# WARNING:tensorflow:Layer gru_1162 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.002295655975533071, RMSE: 0.04791300424240867
#
# WARNING:tensorflow:Layer gru_1163 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.004706120057333301, RMSE: 0.06860116658871991
#
# 하계2동 마실거리, Best MSE=0.0020131215327556123
# Best parameters:
#     - num_dense_layers=3
#     - num_input_nodes=167
#     - num_dense_nodes=22
#     - activation=relu
#     - batch_size=6
# WARNING:tensorflow:Layer gru_1164 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.015426845530129223, RMSE: 0.12420485308605789
#
# WARNING:tensorflow:Layer gru_1165 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.024714242755629445, RMSE: 0.1572076421667517
#
# WARNING:tensorflow:Layer gru_1166 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.07315348077576388, RMSE: 0.2704690015062057
#
# WARNING:tensorflow:Layer gru_1167 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.06748501930358616, RMSE: 0.25977878917183783
#
# WARNING:tensorflow:Layer gru_1168 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.08096075602438603, RMSE: 0.28453603642488945
#
# WARNING:tensorflow:Layer gru_1169 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.053853322584941354, RMSE: 0.23206318662153494
#
# WARNING:tensorflow:Layer gru_1170 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.018726395256541798, RMSE: 0.13684441989552149
#
# WARNING:tensorflow:Layer gru_1171 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.06724071296923359, RMSE: 0.25930814289033344
#
# WARNING:tensorflow:Layer gru_1172 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.05913831891287169, RMSE: 0.24318371432493519
#
# WARNING:tensorflow:Layer gru_1173 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.020507898610678293, RMSE: 0.1432057911213031
#
# WARNING:tensorflow:Layer gru_1174 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.02758870692464438, RMSE: 0.1660984856181548
#
# WARNING:tensorflow:Layer gru_1175 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.028645468949574347, RMSE: 0.16924972363219487
#
# 황학동 마실거리, Best MSE=0.015426845530129223
# Best parameters:
#     - num_dense_layers=1
#     - num_input_nodes=512
#     - num_dense_nodes=13
#     - activation=relu
#     - batch_size=32
# WARNING:tensorflow:Layer gru_1176 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0013063323229594074, RMSE: 0.03614321959869385
#
# WARNING:tensorflow:Layer gru_1177 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.003252748395325107, RMSE: 0.05703287118254794
#
# WARNING:tensorflow:Layer gru_1178 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0021075855034582633, RMSE: 0.04590844697284219
#
# WARNING:tensorflow:Layer gru_1179 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0022785393384442665, RMSE: 0.047734047999769165
#
# WARNING:tensorflow:Layer gru_1180 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.03917770970342121, RMSE: 0.19793359922817855
#
# WARNING:tensorflow:Layer gru_1181 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0013011831319401578, RMSE: 0.03607191611129298
#
# WARNING:tensorflow:Layer gru_1182 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.0027893891737035864, RMSE: 0.052814668168072273
#
# WARNING:tensorflow:Layer gru_1183 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.050795073234405595, RMSE: 0.2253776236328833
#
# WARNING:tensorflow:Layer gru_1184 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.00400216486851902, RMSE: 0.06326266567667711
#
# WARNING:tensorflow:Layer gru_1185 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.04722930204255699, RMSE: 0.2173230361525372
#
# WARNING:tensorflow:Layer gru_1186 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.038795946763532485, RMSE: 0.19696686717194972
#
# WARNING:tensorflow:Layer gru_1187 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
#
# MSE: 0.001384936469486536, RMSE: 0.03721473457498436
#
# 회현동 마실거리, Best MSE=0.0013011831319401578
# Best parameters:
#     - num_dense_layers=1
#     - num_input_nodes=355
#     - num_dense_nodes=38
#     - activation=relu
#     - batch_size=3
